# %%
import pandas as pd

# %%
df = pd.read_csv('10_Property_stolen_and_recovered.csv')

# %%
df.shape
# Out:
# (2449, 8)

# %%
df.head()
# Out:
#                    Area_Name  Year           Group_Name Sub_Group_Name  \
# 0  Andaman & Nicobar Islands  2001  Burglary - Property    3. Burglary
# 1             Andhra Pradesh  2001  Burglary - Property    3. Burglary
# 2          Arunachal Pradesh  2001  Burglary - Property    3. Burglary
# 3                      Assam  2001  Burglary - Property    3. Burglary
# 4                      Bihar  2001  Burglary - Property    3. Burglary
#
#    Cases_Property_Recovered  Cases_Property_Stolen  \
# 0                        27                     64
# 1                      3321                   7134
# 2                        66                    248
# 3                       539                   2423
# 4                       367                   3231
#
#    Value_of_Property_Recovered  Value_of_Property_Stolen
# 0                       755858                   1321961
# 1                     51483437                 147019348
# ...

# %%
df.describe()
# Out:
#               Year  Cases_Property_Recovered  Cases_Property_Stolen  \
# count  2449.000000               2449.000000            2449.000000
# mean   2005.499388               1232.892201            3419.420988
# std       2.873294               3079.573907            8136.256820
# min    2001.000000                  0.000000               0.000000
# 25%    2003.000000                 13.000000              45.000000
# 50%    2005.000000                113.000000             358.000000
# 75%    2008.000000                722.000000            1875.000000
# max    2010.000000              27960.000000           80663.000000
#
#        Value_of_Property_Recovered  Value_of_Property_Stolen
# count                 2.449000e+03              2.449000e+03
# mean                  5.859924e+07              2.465431e+08
# std                   2.494403e+08              9.670035e+08
# min                   0.000000e+00              0.000000e+00
# ...

# %%
pd.unique(df['Group_Name'])
# Out:
# array(['Burglary - Property', 'Criminal Breach of Trust - Property',
#        'Dacoity -Property', 'Other heads of Property',
#        'Robbery - Property', 'Theft - Property', 'Total Property'], dtype=object)

# %%
pd.unique(df['Area_Name'])
# Out:
# array(['Andaman & Nicobar Islands', 'Andhra Pradesh', 'Arunachal Pradesh',
#        'Assam', 'Bihar', 'Chandigarh', 'Chhattisgarh',
#        'Dadra & Nagar Haveli', 'Daman & Diu', 'Delhi', 'Goa', 'Gujarat',
#        'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir', 'Jharkhand',
#        'Karnataka', 'Kerala', 'Lakshadweep', 'Madhya Pradesh',
#        'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland',
#        'Odisha', 'Puducherry', 'Punjab', 'Rajasthan', 'Sikkim',
#        'Tamil Nadu', 'Tripura', 'Uttar Pradesh', 'Uttarakhand',
#        'West Bengal'], dtype=object)

# %%
df[(df['Area_Name'] == 'Delhi') & (df['Group_Name'] == 'Dacoity -Property')]
# Out:
#      Area_Name  Year         Group_Name Sub_Group_Name  \
# 709      Delhi  2001  Dacoity -Property     1. Dacoity
# 744      Delhi  2002  Dacoity -Property     1. Dacoity
# 779      Delhi  2003  Dacoity -Property     1. Dacoity
# 814      Delhi  2004  Dacoity -Property     1. Dacoity
# 849      Delhi  2005  Dacoity -Property     1. Dacoity
# 884      Delhi  2006  Dacoity -Property     1. Dacoity
# 919      Delhi  2007  Dacoity -Property     1. Dacoity
# 954      Delhi  2008  Dacoity -Property     1. Dacoity
# 989      Delhi  2009  Dacoity -Property     1. Dacoity
# 1024     Delhi  2010  Dacoity -Property     1. Dacoity
#
#       Cases_Property_Recovered  Cases_Property_Stolen  \
# 709                         29                     48
# 744                         42                     47
# 779                         27                     28
# 814                         29                     30
# 849                         26                     27
# ...

# %%
# df[(df['Area_Name'].startswith('D')) & (df['Group_Name'] == 'Dacoity -Property')]
# list(filter(lambda n : n.startswith('D'), df['Area_Name']))
d = []
def search(n):
    if n.startswith('D'):
        d.append(n)
    return d

# d = []
# for data in df['Area_Name']:
#     d.append(search(data))

for data in df['Area_Name']:
    search(data)

# %%
d
# Out:
# ['Dadra & Nagar Haveli',
#  'Daman & Diu',
#  'Delhi',
#  'Dadra & Nagar Haveli',
#  'Daman & Diu',
#  'Delhi',
#  'Dadra & Nagar Haveli',
#  'Daman & Diu',
#  'Delhi',
#  'Dadra & Nagar Haveli',
#  'Daman & Diu',
#  'Delhi',
#  'Dadra & Nagar Haveli',
#  'Daman & Diu',
#  'Delhi',
#  'Dadra & Nagar Haveli',
#  'Daman & Diu',
#  'Delhi',
#  'Dadra & Nagar Haveli',
#  'Daman & Diu',
#  'Delhi',
#  'Dadra & Nagar Haveli',
#  'Daman & Diu',
#  'Delhi',
#  'Dadra & Nagar Haveli',
#  'Daman & Diu',
#  'Delhi',
#  'Dadra & Nagar Haveli',
#  'Daman & Diu',
#  'Delhi',
#  'Dadra & Nagar Haveli',
#  'Daman & Diu',
#  'Delhi',
#  'Dadra & Nagar Haveli',
#  'Daman & Diu',
#  'Delhi',
#  'Dadra & Nagar Haveli',
#  'Daman & Diu',
#  'Delhi',
#  'Dadra & Nagar Haveli',
#  'Daman & Diu',
#  'Delhi',
#  'Dadra & Nagar Haveli',
#  'Daman & Diu',
#  'Delhi',
#  'Dadra & Nagar Haveli',
#  'Daman & Diu',
#  'Delhi',
#  'Dadra & Nagar Haveli',
#  'Daman & Diu',
#  'Delhi',
#  'Dadra & Nagar Haveli',
# ...
